# %% [markdown]
# <h2 style="color:green" align="center"> Aprendizaje Automático Con Python: Regresión Lineal Múltiples Variables</h2>

# %% [markdown]
# <h3 style="color:purple">Problema de ejemplo de predicción de precios de viviendas en Monroe, Nueva Jersey (EE.UU.)</h3>

# %% [markdown]
# A continuación se muestra la tabla con precios de viviendas en Monroe Twp, NJ. Aquí el precio depende del **área (pies cuadrados), número de habitaciones y antigüedad de la vivienda (en años)**. Dados estos precios, tenemos que predecir los precios de nuevas viviendas basándonos en el área, número de habitaciones y antigüedad.

# %% [markdown]
# <img src="homeprices.jpg" style='height:200px;width:350px'>

# %% [markdown]
# Dados estos precios de viviendas, encuentra el precio de una vivienda que tiene:
#
# **3000 pies cuadrados de área, 3 habitaciones, 40 años de antigüedad**
#
# **2500 pies cuadrados de área, 4 habitaciones, 5 años de antigüedad**

# %% [markdown]
# Usaremos regresión con múltiples variables aquí. El precio se puede calcular usando la siguiente ecuación:

# %% [markdown]
# <img src="equation.jpg" >

# %% [markdown]
# Aquí área, habitaciones y antigüedad se llaman variables independientes o **características**, mientras que el precio es una variable dependiente

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv('homeprices.csv')
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df.isnull().sum()
# Out:
# area        0
# bedrooms    1
# age         0
# price       0
# dtype: int64

# %%
#df.dropna(inplace=True)
df2 = df.dropna()
df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %% [markdown]
# **Preprocesamiento de Datos: Llenar valores NA con el valor de la mediana de la columna**

# %%
df.bedrooms.median()
# Out:
# 4.0

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df.bedrooms = df.bedrooms.fillna(df.bedrooms.median())
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg = linear_model.LinearRegression()
reg.fit(df.drop('price',axis='columns').values,df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
reg.intercept_
# Out:
# np.float64(14910.231291544944)

# %% [markdown]
# **Encontrar el precio de una vivienda con 3000 pies cuadrados de área, 3 habitaciones, 40 años de antigüedad**

# %%
reg.predict([[3000, 3, 40]])
# Out:
# array([498408.25158031])

# %%
112.06244194*3000 + 23388.88007794*3 + -3231.71790863*40 + 221323.00186540384
# Out:
# 498408.25157402386

# %% [markdown]
# **Encontrar el precio de una vivienda con 2500 pies cuadrados de área, 4 habitaciones, 5 años de antigüedad**

# %%
reg.predict([[2500, 4, 5]])
# Out:
# array([578876.03748933])

# %% [markdown]
# <h3>Ejercicio<h3>

# %% [markdown]
# En la carpeta de ejercicios (mismo nivel que este notebook en GitHub) está el archivo **hiring.csv**. Este archivo contiene estadísticas de contratación de una empresa como la experiencia del candidato, su puntuación en la prueba escrita y la puntuación en la entrevista personal. Basándose en estos 3 factores, Recursos Humanos decidirá el salario. Dados estos datos, necesitas construir un modelo de aprendizaje automático para el departamento de RRHH que les ayude a decidir los salarios para futuros candidatos. Usando esto, predice los salarios para los siguientes candidatos:
#
#
# **2 años de experiencia, 9 puntos en la prueba, 6 puntos en la entrevista**
#
# **12 años de experiencia, 10 puntos en la prueba, 10 puntos en la entrevista**

# %%
df = pd.read_csv('Exercise/hiring.csv')
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# Cargar los datos
df = pd.read_csv("Exercise/hiring.csv")

# Diccionario para convertir palabras a números
word_to_num = {
    'zero': 0,
    'one': 1,
    'two': 2,
    'three': 3,
    'four': 4,
    'five': 5,
    'six': 6,
    'seven': 7,
    'eight': 8,
    'nine': 9,
    'ten': 10,
    'eleven': 11,
    'twelve': 12
}

# Función para convertir experiencia de texto a número
def convert_experience(x):
    if pd.isnull(x):
        return np.nan
    x = str(x).lower().strip()
    return word_to_num.get(x, np.nan)

# Aplicar conversión
df['experience'] = df['experience'].apply(convert_experience)

# Reemplazar valores nulos por la media de la columna
df['experience'] = df['experience'].fillna(df['experience'].mean())
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(df['test_score(out of 10)'].mean())

print("✅ Nueva base de datos limpia:\n")
print(df)

# Variables independientes (X) y dependiente (y)
X = df[['experience', 'test_score(out of 10)', 'interview_score(out of 10)']]
y = df['salary($)']

# Crear y entrenar modelo
reg = linear_model.LinearRegression()
reg.fit(X, y)

# ---- Predicciones ----
pred_1 = reg.predict([[2, 9, 6]])    # Candidato 1
pred_2 = reg.predict([[12, 10, 10]]) # Candidato 2

# Mostrar resultados
print("\n💼 Predicciones de salario:")
print(f"➡️ Candidato 1 (2 años, 9 test, 6 entrevista): ${pred_1[0]:.2f}")
print(f"➡️ Candidato 2 (12 años, 10 test, 10 entrevista): ${pred_2[0]:.2f}")
# Out:
# ✅ Nueva base de datos limpia:
#
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0    6.333333               8.000000                           9      50000
# 1    6.333333               8.000000                           6      45000
# 2    5.000000               6.000000                           7      60000
# 3    2.000000              10.000000                          10      65000
# 4    7.000000               9.000000                           6      70000
# 5    3.000000               7.000000                          10      62000
# 6   10.000000               7.857143                           7      72000
# 7   11.000000               7.000000                           8      80000
#
# 💼 Predicciones de salario:
# ➡️ Candidato 1 (2 años, 9 test, 6 entrevista): $47738.89
# ➡️ Candidato 2 (12 años, 10 test, 10 entrevista): $86424.67
# ...

# %% [markdown]
# <h3>Respuesta<h3>

# %% [markdown]
# 53713.86 and 93747.79
